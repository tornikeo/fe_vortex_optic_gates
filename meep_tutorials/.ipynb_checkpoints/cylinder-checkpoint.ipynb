# %%
import meep as mp
import numpy as np
import matplotlib.pyplot as plt

resolution = 10  # pixels/um

sx = 16  # size of cell in X direction
sy = 16  # size of cell in Y direction
cell = mp.Vector3(sx, sy, 0)

dpml = 1.0
pml_layers = [mp.PML(dpml)]
resolution = 10

# %%
from meep import materials

# %%
pad = 4 # Pad distance between waveguide and cell edge
w = 1 # width of waveguide, micrometers

# %%
wavelength = w * 430.501 / 538.126

# %%
fcen = 1/wavelength
df = fcen * .1

sources = [
    mp.Source(
        mp.GaussianSource(fcen, fwidth=df),
        component=mp.Ez,
        center=mp.Vector3(-0.5 * sx + dpml, 0, 0),
        size=mp.Vector3(0,w,0)
    )
]

# %%
sim = mp.Simulation(
    cell_size=cell,
    boundary_layers=pml_layers,
    geometry=[],
    sources=sources,
    resolution=resolution,
)

nfreq = 100

# Reflected flux
refl_fr = mp.FluxRegion(
    center=mp.Vector3(-0.5*sx + dpml + 0.5, 0, 0),
    size=mp.Vector3(0, 2*w, 0)
)

refl = sim.add_flux(fcen, df, nfreq, refl_fr)

tran_fr = mp.FluxRegion(
    center=mp.Vector3(0.5 * sx - dpml, 0, 0),
    size=mp.Vector3(0, 2 * w, 0)
)

tran = sim.add_flux(fcen, df, nfreq, tran_fr)
plt.figure(dpi=150,)
sim.plot2D()
plt.show();
# Out:
# /home/tornikeo/miniconda3/envs/vortex/lib/python3.8/site-packages/numpy/core/getlimits.py:500: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/tornikeo/miniconda3/envs/vortex/lib/python3.8/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)

# %%
import time

pt = mp.Vector3(0.5 * sx - dpml - 0.5, 0)

f = plt.figure(dpi=150)
Animate = mp.Animate2D(fields=mp.Ez, f=f, realtime=False, normalize=True)
sim.run(
    mp.at_every(10, Animate),
    until_after_sources = mp.stop_when_fields_decayed(
        dt=50, c=mp.Ez, pt=pt, decay_by=1e-3,)
)
plt.close()
# !mkdir -p media
filename = f'media/{time.strftime("%Y%m%d-%H%M%S")}.mp4'
fps = 10
Animate.to_mp4(fps, filename)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00165105 s
# Working in 2D dimensions.
# Computational cell is 16 x 16 x 0 with resolution 200
# time for set_epsilon = 8.66781 s
# -----------
# on time step 38 (time=0.095), 0.105574 s/step
# on time step 105 (time=0.2625), 0.0598022 s/step
# on time step 165 (time=0.4125), 0.0670817 s/step
# on time step 220 (time=0.55), 0.0732158 s/step
# on time step 278 (time=0.695), 0.0697593 s/step
# on time step 336 (time=0.84), 0.0698007 s/step
# on time step 395 (time=0.9875), 0.0683708 s/step
# on time step 452 (time=1.13), 0.0707967 s/step
# on time step 519 (time=1.2975), 0.060304 s/step
# on time step 594 (time=1.485), 0.0539513 s/step
# on time step 669 (time=1.6725), 0.0537661 s/step
# on time step 744 (time=1.86), 0.0537326 s/step
# on time step 818 (time=2.045), 0.0542653 s/step
# on time step 893 (time=2.2325), 0.0539868 s/step
# on time step 968 (time=2.42), 0.0536864 s/step
# on time step 1043 (time=2.6075), 0.0539042 s/step
# on time step 1118 (time=2.795), 0.0536443 s/step
# on time step 1193 (time=2.9825), 0.0538354 s/step
# on time step 1268 (time=3.17), 0.0535388 s/step
# on time step 1342 (time=3.355), 0.0540597 s/step
# on time step 1417 (time=3.5425), 0.0534802 s/step
# on time step 1492 (time=3.73), 0.0534932 s/step
# on time step 1567 (time=3.9175), 0.0538273 s/step
# on time step 1642 (time=4.105), 0.0535794 s/step
# on time step 1717 (time=4.2925), 0.0538109 s/step
# on time step 1792 (time=4.48), 0.0536493 s/step
# on time step 1867 (time=4.6675), 0.0537793 s/step
# on time step 1942 (time=4.855), 0.0538025 s/step
# on time step 2017 (time=5.0425), 0.053418 s/step
# on time step 2092 (time=5.23), 0.053697 s/step
# on time step 2167 (time=5.4175), 0.0537538 s/step
# on time step 2242 (time=5.605), 0.053743 s/step
# on time step 2317 (time=5.7925), 0.0535825 s/step
# on time step 2392 (time=5.98), 0.0535003 s/step
# on time step 2467 (time=6.1675), 0.0540145 s/step
# on time step 2542 (time=6.355), 0.0537119 s/step
# on time step 2617 (time=6.5425), 0.0535109 s/step
# on time step 2692 (time=6.73), 0.0538138 s/step
# on time step 2767 (time=6.9175), 0.0537083 s/step
# on time step 2842 (time=7.105), 0.053536 s/step
# on time step 2917 (time=7.2925), 0.0539957 s/step
# on time step 2992 (time=7.48), 0.0537305 s/step
# on time step 3067 (time=7.6675), 0.0538507 s/step
# on time step 3142 (time=7.855), 0.0537479 s/step
# on time step 3217 (time=8.0425), 0.0540371 s/step
# on time step 3292 (time=8.23), 0.0538837 s/step
# on time step 3367 (time=8.4175), 0.053877 s/step
# on time step 3442 (time=8.605), 0.0537864 s/step
# on time step 3517 (time=8.7925), 0.0535501 s/step
# on time step 3592 (time=8.98), 0.0537106 s/step
# on time step 3667 (time=9.1675), 0.0536035 s/step
# on time step 3742 (time=9.355), 0.0538706 s/step
# on time step 3817 (time=9.5425), 0.0538126 s/step
# on time step 3892 (time=9.73), 0.0535624 s/step
# on time step 3967 (time=9.9175), 0.0536487 s/step
# on time step 4014 (time=10.035), 0.0853439 s/step
# on time step 4089 (time=10.2225), 0.053827 s/step
# on time step 4164 (time=10.41), 0.0536796 s/step
# on time step 4239 (time=10.5975), 0.0535471 s/step
# on time step 4314 (time=10.785), 0.0538893 s/step
# on time step 4389 (time=10.9725), 0.0535386 s/step
# on time step 4464 (time=11.16), 0.053984 s/step
# on time step 4539 (time=11.3475), 0.0535131 s/step
# on time step 4614 (time=11.535), 0.0536083 s/step
# on time step 4688 (time=11.72), 0.0546573 s/step
# on time step 4763 (time=11.9075), 0.0534854 s/step
# on time step 4838 (time=12.095), 0.0538344 s/step
# on time step 4913 (time=12.2825), 0.0536733 s/step
# on time step 4988 (time=12.47), 0.0537143 s/step
# on time step 5063 (time=12.6575), 0.0538638 s/step
# on time step 5138 (time=12.845), 0.0534814 s/step
# on time step 5213 (time=13.0325), 0.0537266 s/step
# on time step 5288 (time=13.22), 0.0537283 s/step
# on time step 5363 (time=13.4075), 0.053782 s/step
# on time step 5438 (time=13.595), 0.0536822 s/step
# on time step 5513 (time=13.7825), 0.0535015 s/step
# on time step 5588 (time=13.97), 0.0537161 s/step
# on time step 5663 (time=14.1575), 0.0536131 s/step
# on time step 5738 (time=14.345), 0.0537299 s/step
# on time step 5813 (time=14.5325), 0.0536841 s/step
# on time step 5888 (time=14.72), 0.0536757 s/step
# on time step 5963 (time=14.9075), 0.0534869 s/step
# on time step 6038 (time=15.095), 0.0537281 s/step
# on time step 6113 (time=15.2825), 0.0536573 s/step
# on time step 6187 (time=15.4675), 0.0541226 s/step
# on time step 6261 (time=15.6525), 0.0541387 s/step
# on time step 6335 (time=15.8375), 0.0541878 s/step
# on time step 6410 (time=16.025), 0.0534929 s/step
# on time step 6485 (time=16.2125), 0.0535762 s/step
# on time step 6560 (time=16.4), 0.0536357 s/step
# on time step 6635 (time=16.5875), 0.0535735 s/step
# on time step 6710 (time=16.775), 0.0534383 s/step
# on time step 6785 (time=16.9625), 0.0534608 s/step
# on time step 6860 (time=17.15), 0.0537789 s/step
# on time step 6934 (time=17.335), 0.0541805 s/step
# on time step 7009 (time=17.5225), 0.0537371 s/step
# on time step 7084 (time=17.71), 0.0534327 s/step
# on time step 7159 (time=17.8975), 0.0535757 s/step
# on time step 7234 (time=18.085), 0.0535357 s/step
# on time step 7308 (time=18.27), 0.0543309 s/step
# on time step 7383 (time=18.4575), 0.0539489 s/step
# on time step 7458 (time=18.645), 0.0536445 s/step
# on time step 7533 (time=18.8325), 0.0535318 s/step
# on time step 7608 (time=19.02), 0.053823 s/step
# on time step 7683 (time=19.2075), 0.0537611 s/step
# on time step 7758 (time=19.395), 0.0538805 s/step
# on time step 7833 (time=19.5825), 0.0538906 s/step
# on time step 7908 (time=19.77), 0.0539413 s/step
# on time step 7983 (time=19.9575), 0.0534069 s/step
# on time step 8050 (time=20.125), 0.060028 s/step
# on time step 8125 (time=20.3125), 0.0537887 s/step
# on time step 8200 (time=20.5), 0.0536763 s/step
# on time step 8275 (time=20.6875), 0.0538698 s/step
# on time step 8350 (time=20.875), 0.05353 s/step
# on time step 8425 (time=21.0625), 0.0536015 s/step
# on time step 8500 (time=21.25), 0.053874 s/step
# on time step 8575 (time=21.4375), 0.0535756 s/step
# on time step 8650 (time=21.625), 0.0537445 s/step
# on time step 8725 (time=21.8125), 0.0536939 s/step
# on time step 8800 (time=22), 0.05351 s/step
# on time step 8875 (time=22.1875), 0.0533622 s/step
# on time step 8950 (time=22.375), 0.0537923 s/step
# on time step 9025 (time=22.5625), 0.0534628 s/step
# on time step 9100 (time=22.75), 0.0536899 s/step
# on time step 9175 (time=22.9375), 0.0538749 s/step
# on time step 9250 (time=23.125), 0.0534912 s/step
# on time step 9325 (time=23.3125), 0.0536032 s/step
# on time step 9400 (time=23.5), 0.0535842 s/step
# on time step 9475 (time=23.6875), 0.0535454 s/step
# on time step 9550 (time=23.875), 0.0538703 s/step
# on time step 9625 (time=24.0625), 0.0537292 s/step
# on time step 9700 (time=24.25), 0.0539667 s/step
# on time step 9775 (time=24.4375), 0.053408 s/step
# on time step 9850 (time=24.625), 0.053557 s/step
# on time step 9925 (time=24.8125), 0.0536141 s/step
# on time step 10000 (time=25), 0.0536986 s/step
# on time step 10075 (time=25.1875), 0.0535626 s/step
# on time step 10150 (time=25.375), 0.0537334 s/step
# on time step 10225 (time=25.5625), 0.0537584 s/step
# on time step 10300 (time=25.75), 0.0540177 s/step
# on time step 10375 (time=25.9375), 0.0536597 s/step
# on time step 10450 (time=26.125), 0.0537476 s/step
# on time step 10524 (time=26.31), 0.0541275 s/step
# on time step 10599 (time=26.4975), 0.0539426 s/step
# on time step 10674 (time=26.685), 0.0535553 s/step
# on time step 10749 (time=26.8725), 0.0535959 s/step
# on time step 10824 (time=27.06), 0.0537929 s/step
# on time step 10899 (time=27.2475), 0.0538222 s/step
# on time step 10974 (time=27.435), 0.0536009 s/step
# on time step 11049 (time=27.6225), 0.0536041 s/step
# on time step 11124 (time=27.81), 0.0539935 s/step
# on time step 11199 (time=27.9975), 0.0539269 s/step
# on time step 11274 (time=28.185), 0.0535977 s/step
# on time step 11348 (time=28.37), 0.0541667 s/step
# on time step 11422 (time=28.555), 0.0541373 s/step
# on time step 11497 (time=28.7425), 0.0534793 s/step
# on time step 11572 (time=28.93), 0.0535933 s/step
# on time step 11647 (time=29.1175), 0.0535732 s/step
# on time step 11722 (time=29.305), 0.0536164 s/step
# on time step 11797 (time=29.4925), 0.0537351 s/step
# on time step 11872 (time=29.68), 0.0536369 s/step
# on time step 11946 (time=29.865), 0.0541219 s/step
# on time step 12012 (time=30.03), 0.0606136 s/step
# on time step 12087 (time=30.2175), 0.0534399 s/step
# on time step 12162 (time=30.405), 0.0536937 s/step
# on time step 12237 (time=30.5925), 0.0536073 s/step
# on time step 12312 (time=30.78), 0.0538822 s/step
# on time step 12387 (time=30.9675), 0.0536252 s/step
# on time step 12462 (time=31.155), 0.0537185 s/step
# on time step 12537 (time=31.3425), 0.0536823 s/step
# on time step 12612 (time=31.53), 0.0535623 s/step
# on time step 12687 (time=31.7175), 0.0535915 s/step
# on time step 12762 (time=31.905), 0.0537088 s/step
# on time step 12837 (time=32.0925), 0.0537486 s/step
# on time step 12912 (time=32.28), 0.0535161 s/step
# on time step 12987 (time=32.4675), 0.0537884 s/step
# on time step 13062 (time=32.655), 0.0536349 s/step
# on time step 13137 (time=32.8425), 0.0540061 s/step
# on time step 13212 (time=33.03), 0.053904 s/step
# on time step 13287 (time=33.2175), 0.0539499 s/step
# on time step 13362 (time=33.405), 0.053707 s/step
# on time step 13437 (time=33.5925), 0.0535963 s/step
# on time step 13513 (time=33.7825), 0.0532887 s/step
# on time step 13587 (time=33.9675), 0.0540847 s/step
# on time step 13662 (time=34.155), 0.0536951 s/step
# on time step 13736 (time=34.34), 0.054256 s/step
# on time step 13811 (time=34.5275), 0.0536226 s/step
# on time step 13886 (time=34.715), 0.0535851 s/step
# on time step 13961 (time=34.9025), 0.053822 s/step
# on time step 14037 (time=35.0925), 0.0533147 s/step
# on time step 14112 (time=35.28), 0.0537606 s/step
# on time step 14186 (time=35.465), 0.0540975 s/step
# on time step 14261 (time=35.6525), 0.0538752 s/step
# on time step 14336 (time=35.84), 0.0540075 s/step
# on time step 14411 (time=36.0275), 0.053791 s/step
# on time step 14486 (time=36.215), 0.0538932 s/step
# on time step 14561 (time=36.4025), 0.053706 s/step
# on time step 14636 (time=36.59), 0.0537645 s/step
# on time step 14711 (time=36.7775), 0.0537989 s/step
# on time step 14786 (time=36.965), 0.0538084 s/step
# on time step 14861 (time=37.1525), 0.0537235 s/step
# on time step 14936 (time=37.34), 0.053381 s/step
# on time step 15011 (time=37.5275), 0.0537322 s/step
# on time step 15086 (time=37.715), 0.0536943 s/step
# on time step 15161 (time=37.9025), 0.0535282 s/step
# on time step 15235 (time=38.0875), 0.0540814 s/step
# on time step 15310 (time=38.275), 0.0537928 s/step
# on time step 15385 (time=38.4625), 0.0535273 s/step
# on time step 15460 (time=38.65), 0.053712 s/step
# on time step 15535 (time=38.8375), 0.0534918 s/step
# on time step 15610 (time=39.025), 0.0536584 s/step
# on time step 15685 (time=39.2125), 0.0538366 s/step
# on time step 15760 (time=39.4), 0.0537215 s/step
# on time step 15834 (time=39.585), 0.0544559 s/step
# on time step 15909 (time=39.7725), 0.0536061 s/step
# on time step 15984 (time=39.96), 0.0538973 s/step
# on time step 16051 (time=40.1275), 0.0601242 s/step
# on time step 16126 (time=40.315), 0.0538399 s/step
# on time step 16201 (time=40.5025), 0.0538906 s/step
# on time step 16276 (time=40.69), 0.0537193 s/step
# on time step 16351 (time=40.8775), 0.0537383 s/step
# on time step 16426 (time=41.065), 0.0533915 s/step
# on time step 16501 (time=41.2525), 0.053907 s/step
# on time step 16576 (time=41.44), 0.0537686 s/step
# on time step 16651 (time=41.6275), 0.0536207 s/step
# on time step 16726 (time=41.815), 0.0537295 s/step
# on time step 16801 (time=42.0025), 0.0533969 s/step
# on time step 16876 (time=42.19), 0.0535529 s/step
# on time step 16951 (time=42.3775), 0.0538039 s/step
# on time step 17026 (time=42.565), 0.0538214 s/step
# on time step 17101 (time=42.7525), 0.0536441 s/step
# on time step 17176 (time=42.94), 0.0540327 s/step
# on time step 17250 (time=43.125), 0.0541712 s/step
# on time step 17325 (time=43.3125), 0.0533728 s/step
# on time step 17400 (time=43.5), 0.0534709 s/step
# on time step 17475 (time=43.6875), 0.0537991 s/step
# on time step 17550 (time=43.875), 0.0536289 s/step
# on time step 17625 (time=44.0625), 0.0535238 s/step
# on time step 17700 (time=44.25), 0.0538946 s/step
# on time step 17775 (time=44.4375), 0.0536948 s/step
# on time step 17850 (time=44.625), 0.0538031 s/step
# on time step 17925 (time=44.8125), 0.0537959 s/step
# on time step 17999 (time=44.9975), 0.0541652 s/step
# on time step 18073 (time=45.1825), 0.0542605 s/step
# on time step 18148 (time=45.37), 0.0533765 s/step
# on time step 18223 (time=45.5575), 0.0537717 s/step
# on time step 18298 (time=45.745), 0.0537943 s/step
# on time step 18373 (time=45.9325), 0.0535769 s/step
# on time step 18448 (time=46.12), 0.0537926 s/step
# on time step 18523 (time=46.3075), 0.0538608 s/step
# on time step 18598 (time=46.495), 0.0538347 s/step
# on time step 18673 (time=46.6825), 0.0535666 s/step
# on time step 18748 (time=46.87), 0.0535592 s/step
# on time step 18823 (time=47.0575), 0.0539919 s/step
# on time step 18898 (time=47.245), 0.0538088 s/step
# on time step 18973 (time=47.4325), 0.0535356 s/step
# on time step 19048 (time=47.62), 0.0536903 s/step
# on time step 19123 (time=47.8075), 0.0538784 s/step
# on time step 19198 (time=47.995), 0.0538664 s/step
# on time step 19273 (time=48.1825), 0.0537968 s/step
# on time step 19348 (time=48.37), 0.0538705 s/step
# on time step 19423 (time=48.5575), 0.0537062 s/step
# on time step 19498 (time=48.745), 0.0538323 s/step
# on time step 19573 (time=48.9325), 0.0537822 s/step
# on time step 19648 (time=49.12), 0.0540262 s/step
# on time step 19723 (time=49.3075), 0.0538196 s/step
# on time step 19798 (time=49.495), 0.053958 s/step
# on time step 19873 (time=49.6825), 0.0535681 s/step
# on time step 19947 (time=49.8675), 0.0543294 s/step
# field decay(t = 50.0025): 0.01868535556011587 / 0.01868535556011587 = 1.0
# on time step 20014 (time=50.035), 0.060281 s/step
# on time step 20089 (time=50.2225), 0.0537713 s/step
# on time step 20164 (time=50.41), 0.0539104 s/step
# on time step 20239 (time=50.5975), 0.0540852 s/step
# on time step 20313 (time=50.7825), 0.0542923 s/step
# on time step 20388 (time=50.97), 0.0535639 s/step
# on time step 20463 (time=51.1575), 0.0538873 s/step
# on time step 20538 (time=51.345), 0.0538059 s/step
# on time step 20613 (time=51.5325), 0.0534833 s/step
# on time step 20688 (time=51.72), 0.0536151 s/step
# on time step 20763 (time=51.9075), 0.0535012 s/step
# on time step 20838 (time=52.095), 0.0536514 s/step
# on time step 20913 (time=52.2825), 0.0536082 s/step
# on time step 20988 (time=52.47), 0.0535051 s/step
# on time step 21063 (time=52.6575), 0.0538956 s/step
# on time step 21138 (time=52.845), 0.0536344 s/step
# on time step 21213 (time=53.0325), 0.0536353 s/step
# on time step 21288 (time=53.22), 0.0533705 s/step
# on time step 21363 (time=53.4075), 0.0538375 s/step
# on time step 21438 (time=53.595), 0.0535838 s/step
# on time step 21513 (time=53.7825), 0.0538234 s/step
# on time step 21588 (time=53.97), 0.0534957 s/step
# on time step 21663 (time=54.1575), 0.0536059 s/step
# on time step 21738 (time=54.345), 0.053639 s/step
# on time step 21813 (time=54.5325), 0.0533934 s/step
# on time step 21888 (time=54.72), 0.0533814 s/step
# on time step 21962 (time=54.905), 0.0541683 s/step
# on time step 22036 (time=55.09), 0.0542766 s/step
# on time step 22111 (time=55.2775), 0.0539306 s/step
# on time step 22186 (time=55.465), 0.0537307 s/step
# on time step 22261 (time=55.6525), 0.0536635 s/step
# on time step 22336 (time=55.84), 0.0537263 s/step
# on time step 22410 (time=56.025), 0.0541968 s/step
# on time step 22484 (time=56.21), 0.0542812 s/step
# on time step 22558 (time=56.395), 0.0540673 s/step
# on time step 22633 (time=56.5825), 0.0537337 s/step
# on time step 22708 (time=56.77), 0.0539813 s/step
# on time step 22783 (time=56.9575), 0.0537359 s/step
# on time step 22856 (time=57.14), 0.0550109 s/step
# on time step 22931 (time=57.3275), 0.0535451 s/step
# on time step 23006 (time=57.515), 0.0537219 s/step
# on time step 23081 (time=57.7025), 0.0536424 s/step
# on time step 23156 (time=57.89), 0.0536914 s/step
# on time step 23231 (time=58.0775), 0.0538568 s/step
# on time step 23306 (time=58.265), 0.0539855 s/step
# on time step 23380 (time=58.45), 0.0540578 s/step
# on time step 23454 (time=58.635), 0.0543744 s/step
# on time step 23529 (time=58.8225), 0.0537395 s/step
# on time step 23603 (time=59.0075), 0.0541778 s/step
# on time step 23677 (time=59.1925), 0.0540905 s/step
# on time step 23751 (time=59.3775), 0.0542242 s/step
# on time step 23826 (time=59.565), 0.0536035 s/step
# on time step 23901 (time=59.7525), 0.0538336 s/step
# on time step 23976 (time=59.94), 0.0537249 s/step
# on time step 24043 (time=60.1075), 0.0601291 s/step
# on time step 24118 (time=60.295), 0.053383 s/step
# on time step 24193 (time=60.4825), 0.0535635 s/step
# on time step 24268 (time=60.67), 0.0534545 s/step
# on time step 24343 (time=60.8575), 0.0538885 s/step
# on time step 24418 (time=61.045), 0.0536869 s/step
# on time step 24493 (time=61.2325), 0.0536021 s/step
# on time step 24568 (time=61.42), 0.0538059 s/step
# on time step 24643 (time=61.6075), 0.0535945 s/step
# on time step 24717 (time=61.7925), 0.0543274 s/step
# on time step 24791 (time=61.9775), 0.054066 s/step
# on time step 24865 (time=62.1625), 0.0541007 s/step
# on time step 24940 (time=62.35), 0.0535757 s/step
# on time step 25015 (time=62.5375), 0.0537964 s/step
# on time step 25090 (time=62.725), 0.0538872 s/step
# on time step 25164 (time=62.91), 0.0542434 s/step
# on time step 25238 (time=63.095), 0.0542942 s/step
# on time step 25312 (time=63.28), 0.0543936 s/step
# on time step 25385 (time=63.4625), 0.0550428 s/step
# on time step 25460 (time=63.65), 0.0535343 s/step
# on time step 25535 (time=63.8375), 0.0537946 s/step
# on time step 25610 (time=64.025), 0.0540171 s/step
# on time step 25685 (time=64.2125), 0.0537178 s/step
# on time step 25760 (time=64.4), 0.0540173 s/step
# on time step 25835 (time=64.5875), 0.0538921 s/step
# on time step 25900 (time=64.75), 0.0619097 s/step
# on time step 25963 (time=64.9075), 0.0637745 s/step
# on time step 26023 (time=65.0575), 0.0668089 s/step
# on time step 26084 (time=65.21), 0.0663883 s/step
# on time step 26147 (time=65.3675), 0.0656866 s/step
# on time step 26199 (time=65.4975), 0.0774498 s/step
# on time step 26271 (time=65.6775), 0.056145 s/step
# on time step 26342 (time=65.855), 0.0566642 s/step
# on time step 26409 (time=66.0225), 0.0600241 s/step
# on time step 26471 (time=66.1775), 0.0646997 s/step
# on time step 26540 (time=66.35), 0.0580372 s/step
# on time step 26600 (time=66.5), 0.0671392 s/step
# on time step 26669 (time=66.6725), 0.0581326 s/step
# on time step 26731 (time=66.8275), 0.065256 s/step
# on time step 26803 (time=67.0075), 0.0559816 s/step
# on time step 26871 (time=67.1775), 0.0591004 s/step
# on time step 26936 (time=67.34), 0.0621821 s/step
# on time step 26992 (time=67.48), 0.0718352 s/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [7], line 7
#       5 f = plt.figure(dpi=150)
#       6 Animate = mp.Animate2D(fields=mp.Ez, f=f, realtime=False, normalize=True)
# ----> 7 sim.run(
#       8     mp.at_every(10, Animate),
#       9     until_after_sources = mp.stop_when_fields_decayed(
#      10         dt=50, c=mp.Ez, pt=pt, decay_by=1e-3,)
#      11 )
#      12 plt.close()
#      13 get_ipython().system('mkdir -p media')
#
# File ~/miniconda3/envs/vortex/lib/python3.8/site-packages/meep/simulation.py:4450, in Simulation.run(self, *step_funcs, **kwargs)
#    4447     raise ValueError(f"Unrecognized keyword arguments: {kwargs.keys()}")
#    4449 if until_after_sources is not None:
# -> 4450     self._run_sources_until(until_after_sources, step_funcs)
#    4451 elif until is not None:
#    4452     self._run_until(until, step_funcs)
#
# File ~/miniconda3/envs/vortex/lib/python3.8/site-packages/meep/simulation.py:2676, in Simulation._run_sources_until(self, cond, step_funcs)
#    2672             return cond[i](sim) and sim.round_time() >= ts
#    2674         new_conds.append(f)
# -> 2676 self._run_until(new_conds, step_funcs)
#
# File ~/miniconda3/envs/vortex/lib/python3.8/site-packages/meep/simulation.py:2634, in Simulation._run_until(self, cond, step_funcs)
#    2632     for func in step_funcs:
#    2633         _eval_step_func(self, func, "step")
# -> 2634     self.fields.step()
#    2636 # Translating the recursive scheme version of run-until into an iterative version
#    2637 # (because python isn't tail-call-optimized) means we need one extra iteration to
#    2638 # be the same as scheme.
#    2639 for func in step_funcs:
#
# File ~/miniconda3/envs/vortex/lib/python3.8/site-packages/meep/__init__.py:3069, in fields.step(self)
#    3068 def step(self):
# -> 3069     return _meep.fields_step(self)
#
# KeyboardInterrupt:

# %%
from IPython.display import Video
Video(filename)

# %%
straight_refl_data = sim.get_flux_data(refl)

# %%
straight_tran_flux = mp.get_fluxes(tran)

# %%
sim.reset_meep()
geometry = [
    mp.Cylinder(
        radius=w,
        center=mp.Vector3(0,0,0),
        material=mp.Medium(epsilon=6)
    )
]

sim = mp.Simulation(
    cell_size=cell,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    resolution=resolution,
)

# reflected flux
refl = sim.add_flux(fcen, df, nfreq, refl_fr)

# tran_fr = mp.FluxRegion(
#     center=mp.Vector3(wvg_xcen, 0.5 * sy - dpml - 0.5, 0), size=mp.Vector3(2 * w, 0, 0)
# )
# tran = sim.add_flux(fcen, df, nfreq, tran_fr)

tran_fr = mp.FluxRegion(
    center=mp.Vector3(0.5 * sx - dpml, 0, 0),
    size=mp.Vector3(0, 2 * w, 0)
)
tran = sim.add_flux(fcen, df, nfreq, tran_fr)

# for normal run, load negated fields to subtract incident from refl. fields
sim.load_minus_flux_data(refl, straight_refl_data)

# pt = mp.Vector3(wvg_xcen, 0.5 * sy - dpml - 0.5)
pt = mp.Vector3(0.5 * sx - dpml - 0.5, 0)

plt.figure(dpi=150,)
sim.plot2D()
plt.show();

# %%
Animate = mp.Animate2D(fields=mp.Ez, f=f, realtime=False, normalize=True)
sim.run(
    mp.at_every(10, Animate),
    until_after_sources = mp.stop_when_fields_decayed(
        dt=50, c=mp.Ez, pt=pt, decay_by=1e-3,)
)
plt.close()
# !mkdir -p media
filename = f'media/{time.strftime("%Y%m%d-%H%M%S")}.mp4'
fps = 10
Animate.to_mp4(fps, filename)

bend_refl_flux = mp.get_fluxes(refl)
bend_tran_flux = mp.get_fluxes(tran)

flux_freqs = mp.get_flux_freqs(refl)

# %%
Video(filename)

# %%
wl = []
Rs = []
Ts = []

for i in range(nfreq):
    wl = np.append(wl, 1 / flux_freqs[i])
    Rs = np.append(Rs, -bend_refl_flux[i] / straight_tran_flux[i])
    Ts = np.append(Ts, bend_tran_flux[i] / straight_tran_flux[i])
    

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "bo-", label="reflectance")
    plt.plot(wl, Ts, "ro-", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "go-", label="loss")
#     plt.axis([5.0, 10.0, 0, 1])
    plt.ylim([0,1])
    plt.xlabel("wavelength (μm)")
    plt.legend(loc="upper right")
    plt.show()
